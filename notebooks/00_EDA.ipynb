# %%
import pandas as pd
import numpy as np
import matplotlib as mp
df = pd.read_csv('../data/raw/meme_token_data.csv')

# %%
df
# Out:
#                   id        symbol            name  \
# 0           dogecoin          doge        Dogecoin
# 1          shiba-inu          shib       Shiba Inu
# 2               pepe          pepe            Pepe
# 3     pudgy-penguins         pengu  Pudgy Penguins
# 4               bonk          bonk            Bonk
# ...              ...           ...             ...
# 5249       meerkat-2          merk         Meerkat
# 5250          bear-3          bear            BEAR
# 5251          jaxinu        jaxinu          JAXInu
# 5252   bartholowmeow  bartholomeow   Bartholowmeow
# 5253        psyopcat         psyop        PSYOPCAT
#
#                                                   image  current_price  \
# 0     https://coin-images.coingecko.com/coins/images...       0.236145
# 1     https://coin-images.coingecko.com/coins/images...       0.000013
# 2     https://coin-images.coingecko.com/coins/images...       0.000011
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   id        symbol            name  \
# 0           dogecoin          doge        Dogecoin
# 1          shiba-inu          shib       Shiba Inu
# 2               pepe          pepe            Pepe
# 3     pudgy-penguins         pengu  Pudgy Penguins
# 4               bonk          bonk            Bonk
# ...              ...           ...             ...
# 5249       meerkat-2          merk         Meerkat
# 5250          bear-3          bear            BEAR
# 5251          jaxinu        jaxinu          JAXInu
# 5252   bartholowmeow  bartholomeow   Bartholowmeow
# 5253        psyopcat         psyop        PSYOPCAT
#
#                                                   image  current_price  \
# 0     https://coin-images.coingecko.com/coins/images...       0.236145
# 1     https://coin-images.coingecko.com/coins/images...       0.000013
# 2     https://coin-images.coingecko.com/coins/images...       0.000011
# ...

# %%
df.dtypes
# Out:
# id                                   object
# symbol                               object
# name                                 object
# image                                object
# current_price                       float64
# market_cap                          float64
# market_cap_rank                     float64
# fully_diluted_valuation             float64
# total_volume                        float64
# high_24h                            float64
# low_24h                             float64
# price_change_24h                    float64
# price_change_percentage_24h         float64
# market_cap_change_24h               float64
# market_cap_change_percentage_24h    float64
# circulating_supply                  float64
# total_supply                        float64
# max_supply                          float64
# ath                                 float64
# ath_change_percentage               float64
# ath_date                             object
# ...

# %%
filtered_df = df[(df['market_cap'] < 10000000) & (df['market_cap'] > 100000)]

# %%
filtered_df
# Out:
#                                          id     symbol  \
# 251                              broccoli-3   broccoli
# 252                                  opus-2       opus
# 253                                   leash      leash
# 254                                cocoro-2     cocoro
# 255                                finvesta   finvesta
# ...                                     ...        ...
# 2068                                neiro-4      neiro
# 2069                               wheester      wheee
# 2070  department-of-government-efficiency-3    d.o.g.e
# 2071            ruri-truth-terminal-s-crush       ruri
# 2072                        landlord-roland  $landlord
#
#                                      name  \
# 251                              Broccoli
# 252                                  Opus
# 253                           Doge Killer
# 254                                Cocoro
# 255                              Finvesta
# ...                                   ...
# ...

# %%
candidates = filtered_df.sort_values(by=['market_cap', 'total_volume'], ascending=True).head(50)

# %%
candidates.to_csv('../data/processed/candidates.csv')
